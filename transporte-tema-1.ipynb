# %%
using JuMP, CSV, Clp, GLPK, DataFrames, LinearAlgebra

child = Model(with_optimizer(Clp.Optimizer))

costo=[600 700 400 0;
       320 300 350 0;
       500 480 450 0]
demanda=[30 35 25 5]
oferta=[25;
        40; 
        30]

#Restricción de suministro:

#x₁₁ + x₁₂ + x₁₃  <= 25 sumistro de ciudad 1
#x₂₁ + x₂₂ + x₂₃ <= 40 sumistro de ciudad 2
#x₃₁ + x₃₂ + x₃₃ <= 30 sumistro de ciudad 3

#Restricción de demanda:

#x₁₁ + x₂₁ + x₃₁  <= 30 demanda de ciudad 1
#x₁₂ + x₂₂ + x₃₂  <= 35 demanda de ciudad 2
#x₁₃ + x₂₃ + x₃₃  <= 30 demanda de ciudad 3

@variable(child,x[1:3,1:4]>=0 )  
@objective(child,Min,sum(x.*costo))
for i=1:3
    @constraint(child,sum(x[i,j] for j=1:4)==oferta[i])
end
for j=1:4
@constraint(child,sum(x[i,j] for i=1:3)==demanda[j])
end 
print(child)
JuMP.optimize!(child)
obj_value=JuMP.objective_value(child)

println("Valor func objetivo, El costo minimo es :", obj_value)


println("las asignaciones son")
for i in 1:3
    for j=1:4
        println( "x[",i,",",j, "] = $(JuMP.value(x[i,j] ))")  
    end
end
# Out:
# Min 600 x[1,1] + 320 x[2,1] + 500 x[3,1] + 700 x[1,2] + 300 x[2,2] + 480 x[3,2] + 400 x[1,3] + 350 x[2,3] + 450 x[3,3]
# Subject to
#  x[1,1] ≥ 0.0
#  x[1,2] ≥ 0.0
#  x[1,3] ≥ 0.0
#  x[1,4] ≥ 0.0
#  x[2,1] ≥ 0.0
#  x[2,2] ≥ 0.0
#  x[2,3] ≥ 0.0
#  x[2,4] ≥ 0.0
#  x[3,1] ≥ 0.0
#  x[3,2] ≥ 0.0
#  x[3,3] ≥ 0.0
#  x[3,4] ≥ 0.0
#  x[1,1] + x[1,2] + x[1,3] + x[1,4] = 25.0
#  x[2,1] + x[2,2] + x[2,3] + x[2,4] = 40.0
#  x[3,1] + x[3,2] + x[3,3] + x[3,4] = 30.0
#  x[1,1] + x[2,1] + x[3,1] = 30.0
#  x[1,2] + x[2,2] + x[3,2] = 35.0
#  x[1,3] + x[2,3] + x[3,3] = 25.0
#  x[1,4] + x[2,4] + x[3,4] = 5.0
# Valor func objetivo, El costo minimo es :34600.0
# las asignaciones son
# x[1,1] = 0.0
# x[1,2] = 0.0
# x[1,3] = 25.0
# x[1,4] = 0.0
# x[2,1] = 30.0
# x[2,2] = 10.0
# x[2,3] = 0.0
# x[2,4] = 0.0
# x[3,1] = 0.0
# x[3,2] = 25.0
# x[3,3] = 0.0
# x[3,4] = 5.0
# Coin0506I Presolve 7 (0) rows, 12 (0) columns and 24 (0) elements
# Clp0006I 0  Obj 0 Primal inf 190 (7)
# Clp0006I 8  Obj 34600
# Clp0000I Optimal - objective value 34600
# Clp0032I Optimal objective 34600 - 8 iterations time 0.002
